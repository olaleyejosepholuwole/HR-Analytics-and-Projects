# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # reading the data
# df = pd.read_excel('hr-clean.xlsx')
# print("Shape of dataframe :", df.shape)

# %%
df.head()
# Out:
#    Index  Age              Attrition BusinessTravel  DailyRate  \
# 0      0   41  Voluntary Resignation  Travel_Rarely       1102
# 1      1   37  Voluntary Resignation  Travel_Rarely        807
# 2      2   41  Voluntary Resignation  Travel_Rarely       1102
# 3      3   37  Voluntary Resignation  Travel_Rarely        807
# 4      4   37  Voluntary Resignation  Travel_Rarely        807
#
#         Department  DistanceFromHome  Education   EducationField  \
# 0            Sales                 1          2    Life Sciences
# 1  Human Resources                 6          4  Human Resources
# 2            Sales                 1          2    Life Sciences
# 3  Human Resources                 6          4        Marketing
# 4  Human Resources                 6          4  Human Resources
#
#    Application ID  ...  RelationshipSatisfaction StockOptionLevel  \
# 0          123456  ...                         1                0
# 1          123457  ...                         1                0
# 2          123458  ...                         1                0
# 3          123459  ...                         1                0
# 4          123460  ...                         1                0
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                  8                      0                1              6
# 1                  8                      0                1              6
# 2                  8                      0                1              6
# 3                  8                      0                1              6
# 4                  8                      0                1              6
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   4                       0                     5
# 1                   4                       0                     5
# 2                   4                       0                     5
# 3                   4                       0                     5
# 4                   4                       0                     5
#
#    Employee Source
# 0         Referral
# 1         Referral
# 2         Referral
# 3         Referral
# 4         Referral
#
# [5 rows x 34 columns]

# %%
df.describe(include = 'all')
# Out:
#                Index           Age         Attrition BusinessTravel  \
# count   16218.000000  16218.000000             16218          16218
# unique           NaN           NaN                 3              3
# top              NaN           NaN  Current employee  Travel_Rarely
# freq             NaN           NaN             13572          11476
# mean     8204.735911     37.061968               NaN            NaN
# std      4727.255005      9.225461               NaN            NaN
# min         0.000000     18.000000               NaN            NaN
# 25%      4113.250000     30.000000               NaN            NaN
# 50%      8210.500000     36.000000               NaN            NaN
# 75%     12296.750000     43.000000               NaN            NaN
# max     16383.000000     60.000000               NaN            NaN
#
#            DailyRate              Department  DistanceFromHome     Education  \
# count   16218.000000                   16218      16218.000000  16218.000000
# unique           NaN                       3               NaN           NaN
# top              NaN  Research & Development               NaN           NaN
# freq             NaN                   10287               NaN           NaN
# mean      802.806388                     NaN          9.135837      2.894192
# std       403.289164                     NaN          8.101052      1.029635
# min       102.000000                     NaN          1.000000      1.000000
# 25%       465.000000                     NaN          2.000000      2.000000
# 50%       806.500000                     NaN          7.000000      3.000000
# 75%      1153.000000                     NaN         14.000000      4.000000
# max      1499.000000                     NaN         29.000000      5.000000
#
#        EducationField  Application ID  ...  RelationshipSatisfaction  \
# count           16218    16218.000000  ...              16218.000000
# unique              6             NaN  ...                       NaN
# top     Life Sciences             NaN  ...                       NaN
# freq             7392             NaN  ...                       NaN
# mean              NaN   131647.129116  ...                  2.731964
# std               NaN     4726.607228  ...                  1.088484
# min               NaN   123456.000000  ...                  1.000000
# 25%               NaN   127555.250000  ...                  2.000000
# 50%               NaN   131652.500000  ...                  3.000000
# 75%               NaN   135738.750000  ...                  4.000000
# max               NaN   139825.000000  ...                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count      16218.000000       16218.000000           16218.000000
# unique              NaN                NaN                    NaN
# top                 NaN                NaN                    NaN
# freq                NaN                NaN                    NaN
# mean           0.755519          11.431558               2.769762
# std            0.836282           8.036178               1.305905
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          16.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#         WorkLifeBalance YearsAtCompany  YearsInCurrentRole  \
# count      16218.000000   16218.000000        16218.000000
# unique              NaN            NaN                 NaN
# top                 NaN            NaN                 NaN
# freq                NaN            NaN                 NaN
# mean           2.764028       7.110063            4.257183
# std            0.699894       6.338602            3.621603
# min            1.000000       0.000000            0.000000
# 25%            2.000000       3.000000            2.000000
# 50%            3.000000       5.000000            3.000000
# 75%            3.000000       9.000000            7.000000
# max            4.000000      40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  Employee Source
# count             16218.000000          16218.000000            16218
# unique                     NaN                   NaN                9
# top                        NaN                   NaN  Company Website
# freq                       NaN                   NaN             3831
# mean                  2.203724              4.150018              NaN
# std                   3.281315              3.621532              NaN
# min                   0.000000              0.000000              NaN
# 25%                   0.000000              2.000000              NaN
# 50%                   1.000000              3.000000              NaN
# 75%                   3.000000              7.000000              NaN
# max                  15.000000             17.000000              NaN
#
# [11 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16218 entries, 0 to 16217
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     16218 non-null  int64
#  1   Age                       16218 non-null  int64
#  2   Attrition                 16218 non-null  object
#  3   BusinessTravel            16218 non-null  object
#  4   DailyRate                 16218 non-null  int64
#  5   Department                16218 non-null  object
#  6   DistanceFromHome          16218 non-null  int64
#  7   Education                 16218 non-null  int64
#  8   EducationField            16218 non-null  object
#  9   Application ID            16218 non-null  int64
#  10  EnvironmentSatisfaction   16218 non-null  int64
#  11  Gender                    16218 non-null  object
#  12  HourlyRate                16218 non-null  int64
#  13  JobInvolvement            16218 non-null  int64
#  14  JobLevel                  16218 non-null  int64
#  15  JobRole                   16218 non-null  object
#  16  JobSatisfaction           16218 non-null  int64
#  17  MaritalStatus             16218 non-null  object
#  18  MonthlyIncome             16218 non-null  int64
#  19  MonthlyRate               16218 non-null  int64
#  20  NumCompaniesWorked        16218 non-null  int64
#  21  OverTime                  16218 non-null  object
#  22  PercentSalaryHike         16218 non-null  int64
#  23  PerformanceRating         16218 non-null  int64
#  24  RelationshipSatisfaction  16218 non-null  int64
#  25  StockOptionLevel          16218 non-null  int64
#  26  TotalWorkingYears         16218 non-null  int64
#  27  TrainingTimesLastYear     16218 non-null  int64
#  28  WorkLifeBalance           16218 non-null  int64
#  29  YearsAtCompany            16218 non-null  int64
#  30  YearsInCurrentRole        16218 non-null  int64
#  31  YearsSinceLastPromotion   16218 non-null  int64
#  32  YearsWithCurrManager      16218 non-null  int64
#  33  Employee Source           16218 non-null  object
# dtypes: int64(25), object(9)
# memory usage: 4.2+ MB

# %%
df.isnull().sum()
# Out:
# Index                       0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# Application ID              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# Employee Source             0
# dtype: int64

# %%
# looking at the most popular departments
##****Univariate Data Visualization****##

from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopword = set(STOPWORDS)

stopword = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopword).generate(str(df['Department']))

plt.rcParams['figure.figsize'] = (12, 8)
print(wordcloud)
plt.imshow(wordcloud)
plt.title('Most Popular Departments', fontsize = 30)
plt.axis('off')
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x000001C8775D1C70>

# %%
# checkig the no. of Employees Promoted

df['Employee Source'].value_counts()
# Out:
# Company Website    3831
# Seek               2710
# Indeed             1727
# Jora               1636
# Recruit.net        1635
# LinkedIn           1566
# GlassDoor          1487
# Adzuna             1362
# Referral            264
# Name: Employee Source, dtype: int64

# %%
# plotting a donut chart for visualizing each of the recruitment channel's share

size = [3831,  2710, 1727,1636,  1635,  1566,  1487, 1362, 264]
colors = ['yellow', 'red', 'lightgreen', 'green', 'blue' 'grey', 'orange', 'violet', 'velvet']
labels = "Company Website", "Seek", "Indeed", "Jora", "Recruit.net", "LinkedIn", "GlassDoor", "Adzuna", "Referral"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Showing share of different Recruitment Channels', fontsize = 40)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 10>()
#       7 my_circle = plt.Circle((0, 0), 0.7, color = 'white')
#       9 plt.rcParams['figure.figsize'] = (9, 9)
# ---> 10 plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
#      11 plt.title('Showing share of different Recruitment Channels', fontsize = 40)
#      12 p = plt.gcf()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
#    2745         x, explode=explode, labels=labels, colors=colors,
#    2746         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2747         labeldistance=labeldistance, startangle=startangle,
#    2748         radius=radius, counterclock=counterclock,
#    2749         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2750         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2751         **({"data": data} if data is not None else {}))
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:3094, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3091 x += expl * math.cos(thetam)
#    3092 y += expl * math.sin(thetam)
# -> 3094 w = mpatches.Wedge((x, y), radius, 360. * min(theta1, theta2),
#    3095                    360. * max(theta1, theta2),
#    3096                    facecolor=get_next_color(),
#    3097                    clip_on=False,
#    3098                    label=label)
#    3099 w.set(**wedgeprops)
#    3100 slices.append(w)
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:1153, in Wedge.__init__(self, center, r, theta1, theta2, width, **kwargs)
#    1141 @docstring.dedent_interpd
#    1142 def __init__(self, center, r, theta1, theta2, width=None, **kwargs):
#    1143     """
#    1144     A wedge centered at *x*, *y* center with radius *r* that
#    1145     sweeps *theta1* to *theta2* (in degrees).  If *width* is given,
#    (...)
#    1151     %(Patch:kwdoc)s
#    1152     """
# -> 1153     super().__init__(**kwargs)
#    1154     self.center = center
#    1155     self.r, self.width = r, width
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:99, in Patch.__init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      97 else:
#      98     self.set_edgecolor(edgecolor)
# ---> 99     self.set_facecolor(facecolor)
#     100 # unscaled dashes.  Needed to scale dash patterns by lw
#     101 self._us_dashes = None
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:373, in Patch.set_facecolor(self, color)
#     365 """
#     366 Set the patch face color.
#     367
#    (...)
#     370 color : color or None
#     371 """
#     372 self._original_facecolor = color
# --> 373 self._set_facecolor(color)
#
# File ~\anaconda3\lib\site-packages\matplotlib\patches.py:361, in Patch._set_facecolor(self, color)
#     359     color = mpl.rcParams['patch.facecolor']
#     360 alpha = self._alpha if self._fill else 0
# --> 361 self._facecolor = colors.to_rgba(color, alpha)
#     362 self.stale = True
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:187, in to_rgba(c, alpha)
#     185     rgba = None
#     186 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 187     rgba = _to_rgba_no_colorcycle(c, alpha)
#     188     try:
#     189         _colors_full_map.cache[c, alpha] = rgba
#
# File ~\anaconda3\lib\site-packages\matplotlib\colors.py:262, in _to_rgba_no_colorcycle(c, alpha)
#     258             raise ValueError(
#     259                 f"Invalid string grayscale value {orig_c!r}. "
#     260                 f"Value must be within 0-1 range")
#     261         return c, c, c, alpha if alpha is not None else 1.
# --> 262     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     263 # turn 2-D array into 1-D array
#     264 if isinstance(c, np.ndarray):
#
# ValueError: Invalid RGBA argument: 'bluegrey'

# %%
df['YearsSinceLastPromotion'].value_counts()
# Out:
# 0     6560
# 1     3830
# 2     1664
# 7      840
# 4      722
# 3      593
# 5      452
# 6      334
# 11     327
# 15     204
# 9      203
# 8      157
# 13     109
# 12      96
# 10      79
# 14      48
# Name: YearsSinceLastPromotion, dtype: int64

# %%
#plotting a scatter plot 
#plotting a scatter plot 

plt.hist(df['YearsSinceLastPromotion'])
plt.title('plot to show the gap in Promoted and Non-Promoted Employees', fontsize = 30)
plt.xlabel('Years Since Last Promoted', fontsize = 20)
plt.ylabel('count')
plt.show()

# %%
# checking the distribution of the avg_training score of the Employees

plt.rcParams['figure.figsize'] = (15, 7)
sns.distplot(df['TrainingTimesLastYear'], color = 'blue')
plt.title('Distribution of Training Times LastYear among the Employees', fontsize = 30)
plt.xlabel('Training Times Last Year', fontsize = 20)
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# plotting a donut chart for visualizing each of the recruitment channel's share

size =  [16218, 34]
colors = ['magenta', 'brown']
labels = "Voluntary Resignation", "Current employee"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Showing a Percentage of employees churn  rate', fontsize = 30)
p = plt.gcf()
p.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
df['PerformanceRating' ].value_counts()
# Out:
# 3    13622
# 4     2596
# Name: PerformanceRating, dtype: int64

# %%
# plotting a pie chart


size = [16218, 34]
labels = "Not Met KPI > 80%", "Met KPI > 80%"
colors = ['violet', 'grey']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Gap in Employees in terms of KPI', fontsize = 30)
plt.axis('off')
plt.legend()
plt.show()

# %%
# checking the distribution of length of service

sns.distplot(df['YearsAtCompany'], color = 'green')
plt.title('Distribution of length of service among the Employees', fontsize = 30)
plt.xlabel('Length of Service in years', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df['PerformanceRating'].value_counts().sort_values().plot.bar(color = 'violet', figsize = (15, 7))
plt.title('Distribution of Performance rating of the Employees', fontsize = 30)
plt.xlabel('Ratings', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
df['JobSatisfaction'].value_counts().sort_values().plot.bar(color = 'violet', figsize = (15, 7))
plt.title('Distribution of Level of Employee Satisfaction', fontsize = 30)
plt.xlabel('Ratings', fontsize = 15)
plt.ylabel('count')
plt.show()

# %%
# checking the distribution of age of Employees in the company

sns.distplot(df['Age'], color = 'red')
plt.title('Distribution of Age of Employees', fontsize = 30)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('count')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# checking the different no. of training done by the employees

plt.rcParams['figure.figsize'] = (17, 7)
sns.violinplot(df['TrainingTimesLastYear'], color = 'purple')
plt.title('No. of trainings done by the Employees', fontsize = 30)
plt.xlabel('No. of Trainings', fontsize = 15)
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Employee Source'].value_counts()
# Out:
# Company Website    3831
# Seek               2710
# Indeed             1727
# Jora               1636
# Recruit.net        1635
# LinkedIn           1566
# GlassDoor          1487
# Adzuna             1362
# Referral            264
# Name: Employee Source, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      9459
# Female    6759
# Name: Gender, dtype: int64

# %%
# plotting a pie chart

size = [9459,  6759]
labels = "Male", "Female"
colors = ['yellow', 'orange']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing GenderGap', fontsize = 30)
plt.axis('off')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df['Department'], color = 'pink')
plt.title('Different Regions in the company', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('Region Code', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['YearsSinceLastPromotion' ].value_counts()
# Out:
# 0     6560
# 1     3830
# 2     1664
# 7      840
# 4      722
# 3      593
# 5      452
# 6      334
# 11     327
# 15     204
# 9      203
# 8      157
# 13     109
# 12      96
# 10      79
# 14      48
# Name: YearsSinceLastPromotion, dtype: int64

# %%
df['YearsSinceLastPromotion'].value_counts()
# Out:
# 0     6560
# 1     3830
# 2     1664
# 7      840
# 4      722
# 3      593
# 5      452
# 6      334
# 11     327
# 15     204
# 9      203
# 8      157
# 13     109
# 12      96
# 10      79
# 14      48
# Name: YearsSinceLastPromotion, dtype: int64

# %%
#PerformanceRating

df['PerformanceRating'].value_counts()
# Out:
# 3    13622
# 4     2596
# Name: PerformanceRating, dtype: int64

# %%
# plotting a pie chart


size = [16218, 34]
labels = "Not Met KPI > 80%", "Met KPI > 80%"
colors = ['violet', 'grey']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(size, labels = labels, colors = colors, explode = explode, shadow = True, autopct = "%.2f%%")
plt.title('A Pie Chart Representing Gap in Employees in terms of KPI', fontsize = 30)
plt.axis('off')
plt.legend()
plt.show()

# %%
data = pd.crosstab(df['Attrition'], df['JobSatisfaction'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 8), color = ['magenta', 'purple'])

plt.title('How did the  Churn Rate affect Job Satisfcation Levels Amongst Workers", fontsize = 30)
plt.xlabel('Attrition versus Job Satsifaction Level', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking the different regions of the company

plt.rcParams['figure.figsize'] = (20, 10)
sns.countplot(df['Department'], color = 'pink')
plt.title('Different Department in the company', fontsize = 30)
plt.xticks(rotation = 60)
plt.xlabel('Region Code', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['JobSatisfaction'].value_counts()
# Out:
# 4    5264
# 3    4867
# 1    3136
# 2    2951
# Name: JobSatisfaction, dtype: int64

# %%
#dependency of KPIs with Promotion

data = pd.crosstab(df['WorkLifeBalance'], df['JobSatisfaction'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (10, 8), color = ['pink', 'darkred'])

plt.title('Dependency of  Work Life balance in determining Job Satisfaction', fontsize = 30)
plt.xlabel('KPIs Met or Not', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking dependency on previous years' ratings

data = pd.crosstab(df['PerformanceRating'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (15, 8), color = ['violet', 'pink'])

plt.title('Dependency of Previous year Ratings in determining Promotion', fontsize = 30)
plt.xlabel('Different Ratings', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking how length of service determines the promotion of employees

data = pd.crosstab(df['YearsAtCompany'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['pink', 'lightblue'])

plt.title('Dependency of Length of service in Promotions of Employees', fontsize = 30)
plt.xlabel('Length of service of employees', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking dependency of age factor in promotion of employees

data = pd.crosstab(df['Age'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['lightblue', 'green'])

plt.title('Dependency of Age in determining  Frequency of Promotion of Employees', fontsize = 30)
plt.xlabel('Age of Employees', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking which department got most number of promotions

data = pd.crosstab(df['Department'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['orange', 'lightgreen'])

plt.title('Dependency of Departments in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Different Departments of the Company', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking dependency of gender over promotion

data = pd.crosstab(df['Gender'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (7, 5), color = ['pink', 'yellow'])

plt.title('Dependency of Genders in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Gender', fontsize = 20)
plt.legend()
plt.show()

# %%
# checking which department got most number of promotions

data = pd.crosstab(df['Gender'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['orange', 'lightgreen'])

plt.title('Dependency of Gender in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Different Departments of the Company', fontsize = 20)
plt.legend()
plt.show()

# %%
df.value_counts()
# Out:
# Index  Age  Attrition              BusinessTravel     DailyRate  Department              DistanceFromHome  Education  EducationField  Application ID  EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  JobRole                JobSatisfaction  MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  Employee Source
# 0      41   Voluntary Resignation  Travel_Rarely      1102       Sales                   1                 2          Life Sciences   123456          2                        Female  94          3               2         Sales Executive        4                Single         5993           19479        8                   Yes       11                 3                  1                         0                 8                  0                      1                6               4                   0                        5                     Referral           1
# 10940  34   Voluntary Resignation  Travel_Frequently  296        Sales                   6                 2          Marketing       134382          3                        Male    66          3               1         Research Scientist     4                Single         4678           23293        2                   No        18                 3                  3                         0                 8                  6                      3                6               2                   0                        1                     Company Website    1
# 10927  41   Current employee       Travel_Rarely      645        Sales                   1                 3          Life Sciences   134369          3                        Female  66          3               2         Sales Executive        3                Married        6932           24406        4                   No        13                 3                  4                         1                 9                  2                      2                9               8                   0                        0                     GlassDoor          1
# 10928  31   Current employee       Non-Travel         1188       Sales                   20                2          Marketing       134370          4                        Female  45          3               2         Sales Executive        3                Married        6932           24406        1                   No        13                 3                  4                         1                 9                  2                      2                9               8                   0                        0                     GlassDoor          1
# 10929  41   Current employee       Travel_Rarely      645        Sales                   1                 3          Marketing       134371          3                        Female  66          3               2         Sales Executive        3                Married        6932           24406        1                   No        13                 3                  4                         1                 9                  2                      2                9               8                   0                        0                     GlassDoor          1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ..
# 5482   45   Current employee       Travel_Rarely      1234       Sales                   11                2          Medical         128924          2                        Male    52          2               1         Laboratory Technician  4                Single         3983           7621         1                   No        17                 3                  3                         0                 4                  2                      3                3               2                   2                        2                     Seek               1
# 5483   29   Current employee       Travel_Rarely      738        Research & Development  9                 5          Other           128925          2                        Male    30          2               1         Laboratory Technician  4                Single         3983           7621         0                   No        17                 3                  3                         0                 4                  2                      3                3               2                   2                        2                     Seek               1
# 5484   29   Current employee       Travel_Rarely      738        Research & Development  9                 5          Medical         128926          2                        Male    30          2               1         Laboratory Technician  4                Single         3983           7621         1                   No        17                 3                  3                         0                 4                  2                      3                3               2                   2                        2                     Seek               1
# 5485   45   Current employee       Travel_Rarely      1234       Sales                   11                2          Life Sciences   128927          2                        Male    52          2               1         Laboratory Technician  4                Single         3983           7621         0                   No        17                 3                  3                         0                 4                  2                      3                3               2                   2                        2                     Seek               1
# 16383  24   Current employee       Travel_Rarely      1206       Research & Development  17                1          Medical         139825          3                        Male    82          4               1         Laboratory Technician  3                Single         3500           16092        1                   No        14                 3                  1                         2                 7                  2                      1                6               5                   1                        3                     Company Website    1
# Length: 16218, dtype: int64

# %%
# checking which department got most number of promotions

data = pd.crosstab(df['Gender'], df['YearsSinceLastPromotion'])
data.div(data.sum(1).astype('float'), axis = 0).plot(kind = 'bar', stacked = True, figsize = (20, 8), color = ['orange', 'lightgreen'])

plt.title('Dependency of Departments in determining Promotion of Employees', fontsize = 30)
plt.xlabel('Different Departments of the Company', fontsize = 20)
plt.legend()
plt.show()
